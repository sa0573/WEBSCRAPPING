# %%
from bs4 import BeautifulSoup
import pandas as pd

import requests
def print_heading_with_df(text, df):
    # Print the heading
    display(HTML(f"<h1 style='text-align:center; font-weight:bold;'>{text}</h1>"))

    # Style the DataFrame
    styled_df = df.style.set_table_styles(
        [{'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]}]
    ).set_properties(**{'text-align': 'center'})

    display(styled_df)
url='https://results.eci.gov.in/PcResultGenJune2024/index.htm'
page=requests.get(url)
soup=BeautifulSoup(page.text,'html')
#print(soup)
soup.find('table')
table=soup.find('table',class_='table')
titles=soup.find_all('th')[:4]
#print(titles)
ftitles=[title.text.strip() for title in titles]
#print(ftitles)
df = pd.DataFrame(columns = ftitles)
#df
column_data = table.find_all('tr',class_='tr')
#print(column_data)
for row in column_data[0:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data
df.index = range(1, len(df) + 1)
df
print_heading_with_df("ALL PARTIES RESULTS", df)
# Out:
# <h1 style='text-align:center; font-weight:bold;'>ALL PARTIES RESULTS</h1>
# <style type="text/css">
# #T_3f46e th {
#   font-weight: bold;
#   text-align: center;
# }
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from IPython.display import display, HTML
def print_heading_with_df(text, df):
    # Print the heading
    display(HTML(f"<h1 style='text-align:center; font-weight:bold;'>{text}</h1>"))

    # Style the DataFrame
    styled_df = df.style.set_table_styles(
        [{'selector': 'th', 'props': [('font-weight', 'bold'), ('text-align', 'center')]}]
    ).set_properties(**{'text-align': 'center'})

    display(styled_df)
def extract_headings(soup, class_name):
    main_class = soup.find(class_=class_name)
    headings = []
    if main_class:
        h2_elements = main_class.find_all('h2')
        headings = [heading.text.strip() for heading in h2_elements]
    else:
        print(f"Class '{class_name}' not found on the page.")
    return headings
def DATASHEETS(urls):
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            heading_class = 'page-title'  # Adjust this to the actual class name for headings
            headings = extract_headings(soup, heading_class)

            tablesstate = soup.find('table', class_='table')
            titlesstate = tablesstate.find_all('th')
            titlesstate = [title.text.strip() for title in titlesstate]
            titlesstate = titlesstate[:4]

            df = pd.DataFrame(columns=titlesstate)
            column_data_state = tablesstate.find_all('tr')

            for row in column_data_state[1:]:
                row_data = row.find_all('td')
                individual_row_data_state = [data.text.strip() for data in row_data]
                if any(individual_row_data_state):
                    length = len(df)
                    df.loc[length] = individual_row_data_state

            df.index = range(1, len(df) + 1)
            print_heading_with_df(''.join(headings), df)
url=['https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-U01.htm',
     'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S01.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S02.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S03.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S04.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S05.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S06.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S07.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S08.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S09.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S10.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S11.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S12.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S13.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S14.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S15.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S16.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S17.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S18.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S19.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S20.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S21.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S22.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S23.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S24.htm',
'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S25.htm'
     ]
DATASHEETS(url)
# Out:
# <h1 style='text-align:center; font-weight:bold;'>Andaman & Nicobar Islands (Total PC - 1)</h1>
# <style type="text/css">
# #T_772a8 th {
#   font-weight: bold;
#   text-align: center;
# }
# #T_772a8_row0_col0, #T_772a8_row0_col1, #T_772a8_row0_col2, #T_772a8_row0_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_772a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_772a8_level0_col0" class="col_heading level0 col0" >Party</th>
#       <th id="T_772a8_level0_col1" class="col_heading level0 col1" >Won</th>
#       <th id="T_772a8_level0_col2" class="col_heading level0 col2" >Leading</th>
#       <th id="T_772a8_level0_col3" class="col_heading level0 col3" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_772a8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_772a8_row0_col0" class="data row0 col0" >Bharatiya Janata Party - BJP</td>
# ...

# %% [markdown]
# **Here are 10 key insights extracted from the election results**
#
# **Andhra Pradesh**
#
# Telugu Desam (TDP) won 16 seats.
#
# YSRCP won 4 seats.
#
# BJP won 3 seats.
#
# Janasena Party (JnP) won 2 seats.
#
# **Assam:**
#
#
# BJP won 9 seats.
#
# INC won 3 seats.
#
# UPPL and AGP each won 1 seat.
#
# **Bihar:**
#
#
# JD(U) and BJP each won 12 seats.
#
# LJPRV won 5 seats.
#
# RJD won 4 seats.
#
# INC, CPI(ML)(L), HAMS, and IND each won 1 seat.
#
# **Goa:**
#
#
# BJP and INC each won 1 seat.
#
# **Gujarat:**
#
#
# BJP won all 26 seats.
#
# INC won 1 seat.
#
# **Haryana:**
#
#
#
# INC and BJP each won 5 seats.
#
# **Himachal Pradesh:**
#
#
# BJP won all 4 seats.
#
# **Karnataka:**
#
#
# BJP won 17 seats.
#
# INC won 9 seats.
#
# JD(S) won 2 seats.
#
# **Kerala:**
#
#
# INC won 14 seats.
#
# IUML, CPI(M), BJP, KEC, RSP each won 1 seat.
#
# **Madhya Pradesh:**
#
#
# BJP won all 29 seats.
